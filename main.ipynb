# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("sales_data.csv")

# %%
df.shape
# Out:
# (100, 7)

# %%
df.head()
# Out:
#          Date   Product  Sales_Amount  Profit  Quantity Region  Year
# 0  07-05-2023    Tablet       1136.47  140.04         3   West  2023
# 1  30-04-2023  Keyboard        934.92  102.03         2  South  2023
# 2  07-08-2023  Keyboard        318.55   54.22         3   East  2023
# 3  07-09-2023    Laptop       1083.18  289.52         4   West  2023
# 4  09-08-2023   Monitor       1711.39  194.05         3   East  2023

# %%
df.iloc[:,2:5]
# Out:
#     Sales_Amount  Profit  Quantity
# 0        1136.47  140.04         3
# 1         934.92  102.03         2
# 2         318.55   54.22         3
# 3        1083.18  289.52         4
# 4        1711.39  194.05         3
# ..           ...     ...       ...
# 95        991.98  242.56         6
# 96        238.70   48.38        10
# 97       1690.08  262.13         8
# 98        579.02   67.97         2
# 99       1643.21  351.82        10
#
# [100 rows x 3 columns]

# %%
plt.figure(figsize=(10,6))
plt.scatter(df["Sales_Amount"],df["Profit"])
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,6))
plt.plot(df["Year"],df["Sales_Amount"])
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.iloc[:,2:5].corr()
# Out:
#               Sales_Amount    Profit  Quantity
# Sales_Amount      1.000000  0.817965  0.224784
# Profit            0.817965  1.000000  0.129396
# Quantity          0.224784  0.129396  1.000000

# %%
sns.displot(df["Profit"])

# %%
sns.boxplot(df["Sales_Amount"])
# Out:
# <Axes: ylabel='Sales_Amount'>

# %%
plt.pie(df["Quantity"],startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x2d26dce0c90>,
# ...
#  [Text(-0.01828355915834324, 1.0998480401694153, ''),
#   Text(-0.04874243801661604, 1.0989195488006374, ''),
#   Text(-0.07916390985750829, 1.0971476998909822, ''),
#   Text(-0.1216466829407592, 1.09325298285873, ''),
#   Text(-0.1639464878685365, 1.0877139095900044, ''),
#   Text(-0.18801115721044223, 1.0838135470478263, ''),
#   Text(-0.21198348026722114, 1.0793808429344096, ''),
#   Text(-0.28911381723440105, 1.0613261518893018, ''),
#   Text(-0.39335110511562316, 1.0272657436633998, ''),
#   Text(-0.45519178988403153, 1.0013992382772077, ''),
#   Text(-0.5099496774171889, 0.974654465183485, ''),
#   Text(-0.5891006735563735, 0.9289566170793054, ''),
#   Text(-0.6396412694627118, 0.8949072836892829, ''),
#   Text(-0.6976853648707542, 0.8504323204377658, ''),
#   Text(-0.7831858507253092, 0.7724117575643666, ''),
#   Text(-0.8287794842100067, 0.7232735074317292, ''),
#   Text(-0.8750023607079516, 0.6666114826160078, ''),
# ...

# %%
df.head()
# Out:
#          Date   Product  Sales_Amount  Profit  Quantity Region  Year
# 0  07-05-2023    Tablet       1136.47  140.04         3   West  2023
# 1  30-04-2023  Keyboard        934.92  102.03         2  South  2023
# 2  07-08-2023  Keyboard        318.55   54.22         3   East  2023
# 3  07-09-2023    Laptop       1083.18  289.52         4   West  2023
# 4  09-08-2023   Monitor       1711.39  194.05         3   East  2023

# %%
plt.bar(df["Region"],df["Sales_Amount"],label="Sales")
plt.bar(df["Region"],df["Profit"],label="Profit")
plt.xlabel("Region")
plt.legend()
plt.show()

# %%
plt.bar(df["Year"],df["Sales_Amount"],label="Sales")
plt.bar(df["Year"],df["Profit"],label="Profit")
plt.xlabel("Year")
plt.legend()
plt.show()

# %%
plt.bar(df["Product"],df["Sales_Amount"],label="Sales")
plt.bar(df["Product"],df["Profit"],label="Profit")
plt.xlabel("Product")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.iloc[:,2:5].corr(),annot=True,fmt=".0%")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
plt.scatter(df["Sales_Amount"],df["Quantity"])
plt.xlabel("Sales")
plt.ylabel("Quantity")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,6))
plt.scatter(df["Profit"],df["Quantity"])
plt.xlabel("Profit")
plt.ylabel("Quantity")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.head()
# Out:
#          Date   Product  Sales_Amount  Profit  Quantity Region  Year
# 0  07-05-2023    Tablet       1136.47  140.04         3   West  2023
# 1  30-04-2023  Keyboard        934.92  102.03         2  South  2023
# 2  07-08-2023  Keyboard        318.55   54.22         3   East  2023
# 3  07-09-2023    Laptop       1083.18  289.52         4   West  2023
# 4  09-08-2023   Monitor       1711.39  194.05         3   East  2023

# %%
labels=["Profit","Sales"]
sizes=[["Profit"],["Sales_Amount"]]
colors=["skyblue","lightgreen"]
plt.figure(figsize=(3,3))
plt.pie(sizes,labels=labels,colors=colors,autopct="%1.1f%%",startangle=45)
plt.title("Sales Distribution")
plt.axis("Equal")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 5
#       3 colors=["skyblue","lightgreen"]
#       4 plt.figure(figsize=(3,3))
# ----> 5 plt.pie(sizes,labels=labels,colors=colors,autopct="%1.1f%%",startangle=45)
#       6 plt.title("Sales Distribution")
#       7 plt.axis("Equal")
#
# File c:\Users\BHUMIKA\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3546, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3523 @_copy_docstring_and_deprecators(Axes.pie)
#    3524 def pie(
#    3525     x: ArrayLike,
#    (...)
#    3544     data=None,
#    3545 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3546     return gca().pie(
#    3547         x,
# ...
